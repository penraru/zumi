# %%
import cv2
import IPython.display
import PIL.Image

cutest = cv2.imread('../../recipe/images/axolotl.jpg')

IPython.display.display(PIL.Image.fromarray(flipped))
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x9E61C210>
