# %%
from picamera import PiCamera
import cv2
import IPython.display 
import PIL.Image

# Take a photo with the camera, and save it
camera = PiCamera()
camera.capture("hi.jpg")
camera.close()

# Load the image and display it here
image = cv2.imread("hi.jpg")

# Convert the image space from BGR (Blue, Green, Red) to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Flip it horizontally
image = cv2.flip(image, -1)

IPython.display.display(PIL.Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=720x480 at 0x9EA5AB10>
