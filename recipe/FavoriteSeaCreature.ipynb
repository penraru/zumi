# %%
import time
import cv2
import PIL.Image
import IPython.display
name = input("What is your name? ")
print ("\nHey there " + name + "!")
time.sleep(2)
creature = input("\nWhat is your favorite sea creature? ")
print ("\nI like Axolotls better than " + creature + "s, but that's just my opinion.")
time.sleep(2)
print ("\nLet's load a photo of an Axolotl using openCV. We can switch it for a " + creature + " later....")
time.sleep(2)
print ("\nUse your Trump code to help you figure it out. The image is called: axolotl.jpg")

# Put your code under here. You can delete the intro if it's annoying you ;)

FavoriteSeaCreature = cv2.imread('images/axolotl.jpg')
FavoriteSeaCreature = cv2.cvtColor(FavoriteSeaCreature, cv2.COLOR_BGR2RGB)
IPython.display.display(PIL.Image.fromarray(FavoriteSeaCreature))
# Out:
# What is your name? mylien
#
# Hey there mylien!
#
# What is your favorite sea creature? seahorse
#
# I like Axolotls better than seahorses, but that's just my opinion.
#
# Let's load a photo of an Axolotl using openCV. We can switch it for a seahorse later....
#
# Use your Trump code to help you figure it out. The image is called: axolotl.jpg
# <PIL.Image.Image image mode=RGB size=800x600 at 0x9EACE6F0>
