# %%
# from keras.applications.vgg16 import VGG16
# from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input
import numpy as np
from picamera import PiCamera
from IPython import display

camera = PiCamera()
camera.capture("spy.jpg")
camera.close()
display.display(display.Image("spy.jpg"))

model = VGG16(weights='imagenet', include_top=False)

# img_path = 'elephant.jpg'
img_path = 'spy.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-438f29541374> in <module>()
#      11 display.display(display.Image("spy.jpg"))
#      12
# ---> 13 model = VGG16(weights='imagenet', include_top=False)
#      14
#      15 # img_path = 'elephant.jpg'
#
# NameError: name 'VGG16' is not defined
